# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dadosEnem = pd.read_csv('Microdados2017Tratado.csv',sep=';',encoding='latin1',low_memory=False)

# %%
dadosEnem.astype({'CO_ESCOLA': 'object'})
dadosEnem.astype({'CO_ESCOLA': 'object'})
dadosEnem.astype({'TP_ENSINO': 'int64'}) 
dadosEnem.astype({'CO_MUNICIPIO_PROVA': 'object'})
dadosEnem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177552 entries, 0 to 177551
# Data columns (total 63 columns):
# NO_MUNICIPIO_RESIDENCIA    177552 non-null object
# NU_IDADE                   177552 non-null float64
# TP_SEXO                    177552 non-null object
# TP_COR_RACA                177552 non-null int64
# NO_MUNICIPIO_NASCIMENTO    177552 non-null object
# SG_UF_NASCIMENTO           177552 non-null object
# TP_ST_CONCLUSAO            177552 non-null int64
# TP_ANO_CONCLUIU            177552 non-null int64
# TP_ESCOLA                  177552 non-null int64
# TP_ENSINO                  177552 non-null float64
# IN_TREINEIRO               177552 non-null int64
# CO_ESCOLA                  177552 non-null float64
# NO_MUNICIPIO_ESC           177552 non-null object
# CO_UF_ESC                  177552 non-null float64
# SG_UF_ESC_x                177552 non-null object
# TP_DEPENDENCIA_ADM_ESC     177552 non-null float64
# ...

# %%
dadosResum
# Out:
#        NO_MUNICIPIO_RESIDENCIA       NU_IDADE TP_SEXO  ...    Q025    Q026    Q027
# count                   177552  177552.000000  177552  ...  177552  177552  177552
# unique                    1051            NaN       2  ...       2       4       5
# top             Belo Horizonte            NaN       F  ...       B       B       A
# freq                     22001            NaN  104338  ...  132335  175272  150677
# mean                       NaN      18.859087     NaN  ...     NaN     NaN     NaN
# std                        NaN       4.479463     NaN  ...     NaN     NaN     NaN
# min                        NaN      13.000000     NaN  ...     NaN     NaN     NaN
# 25%                        NaN      17.000000     NaN  ...     NaN     NaN     NaN
# 50%                        NaN      18.000000     NaN  ...     NaN     NaN     NaN
# 75%                        NaN      18.000000     NaN  ...     NaN     NaN     NaN
# ...
