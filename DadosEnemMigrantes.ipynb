# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dadosEnem = pd.read_csv('MicroDadosMG.CSV',sep=';',encoding='latin1',low_memory=False,index_col=0)

dadosEnem.head()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
estudamFora = dadosEnem.query("NO_MUNICIPIO_RESIDENCIA != NO_MUNICIPIO_ESC").count()
estudamFora = estudamFora[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# /usr/lib/python3.6/collections/__init__.py in __getitem__(self, key)
#     882                 pass
# --> 883         return self.__missing__(key)            # support subclasses that define __missing__
#     884
#
# /usr/lib/python3.6/collections/__init__.py in __missing__(self, key)
#     874     def __missing__(self, key):
# --> 875         raise KeyError(key)
#     876
#
# KeyError: 'NO_MUNICIPIO_RESIDENCIA'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
naoFizeramProvaOndeEstudam = dadosEnem.query("NO_MUNICIPIO_ESC != NO_MUNICIPIO_PROVA").count()
naoFizeramProvaOndeEstudam = naoFizeramProvaOndeEstudam[0]

# %%
naoFizeramProvaOndeMoram = dadosEnem.query("NO_MUNICIPIO_PROVA != NO_MUNICIPIO_RESIDENCIA").count()
naoFizeramProvaOndeMoram = naoFizeramProvaOndeMoram[0]

# %%
dadosMigrantes = dadosEnem.query("NO_MUNICIPIO_ESC != NO_MUNICIPIO_PROVA and NO_MUNICIPIO_RESIDENCIA != NO_MUNICIPIO_PROVA")

# %%
cidades_de_migrantes = dadosMigrantes['NO_MUNICIPIO_RESIDENCIA'].value_counts().to_frame().reset_index()
contagemMigrantes = dadosMigrantes['NO_MUNICIPIO_RESIDENCIA'].count()

# %%
dadosReallMigrantes = dadosEnem.query("NO_MUNICIPIO_ESC != NO_MUNICIPIO_PROVA and NO_MUNICIPIO_RESIDENCIA != NO_MUNICIPIO_PROVA and NO_MUNICIPIO_RESIDENCIA != NO_MUNICIPIO_ESC")
contagemMigrantesReais = dadosReallMigrantes.count()

# %%
naoFazemProvaEmMinas = dadosEnem.query("CO_UF_PROVA != 31").count()

# %%
cidades_de_migrantes = dadosReallMigrantes["NO_MUNICIPIO_RESIDENCIA"].value_counts().to_frame().reset_index()
cidades_de_migrantes.columns = ["cidade_residência", "total"]
outros = cidades_de_migrantes.query("total <= 13")
cidades_de_migrantes =  cidades_de_migrantes.query("total > 23")


sns.barplot(x="cidade_residência", y = "total", data = cidades_de_migrantes)

# %% [markdown]
# #Estudam Fora de casa: 6.38%
# #Não fazem Prova onde estudam: 26%
# #Não Fizeram Prova onde Moram: 25.92%
# #Não Fizeram Prova Onde Estudam ou Onde Moram: 23%
# #Não FIzeram Prova em Minas: 1.38%
